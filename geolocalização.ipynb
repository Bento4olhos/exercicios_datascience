# %%
import folium

latitude = -30.0346
longitude = -51.2177

mapa = folium.Map(location=[latitude, longitude], zoom_start=5)

folium.Marker([latitude, longitude], popup='Porto Alegre, RS, Brasil').add_to(mapa)

latitude = -23.5505
longitude = -46.6333


folium.Marker([latitude, longitude], popup='São Paulo, SP, Brasil').add_to(mapa)

latitude = -22.9068
longitude = -43.1729



folium.Marker([latitude, longitude], popup='Rio de Janeiro, RJ, Brasil').add_to(mapa)

latitude = -25.4290
longitude = -49.2671



folium.Marker([latitude, longitude], popup='Curitiba, PR, Brasil').add_to(mapa)

latitude = -19.9173
longitude = -43.9345



folium.Marker([latitude, longitude], popup='Belo Horizonte, SC, Brasil').add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4460d19b0bf610777fb92a2dc43671f1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4460d19b0bf610777fb92a2dc43671f1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4460d19b0bf610777fb92a2dc43671f1 = L.map(
#                 &quot;map_4460d19b0bf610777fb92a2dc43671f1&quot;,
#                 {
#                     center: [-30.0346, -51.2177],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e42513dd9ec3450c09123fcd483aeada = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e42513dd9ec3450c09123fcd483aeada.addTo(map_4460d19b0bf610777fb92a2dc43671f1);
#
#
#             var marker_290dfb799ebe6619c46850354bdfb176 = L.marker(
#                 [-30.0346, -51.2177],
#                 {}
#             ).addTo(map_4460d19b0bf610777fb92a2dc43671f1);
#
#
#         var popup_d38e81fb5452f2716f5a0f9cfd23bbf4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_454ebc0c5e92ccf96009b0ce2df9732f = $(`&lt;div id=&quot;html_454ebc0c5e92ccf96009b0ce2df9732f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Porto Alegre, RS, Brasil&lt;/div&gt;`)[0];
#                 popup_d38e81fb5452f2716f5a0f9cfd23bbf4.setContent(html_454ebc0c5e92ccf96009b0ce2df9732f);
#
#
#
#         marker_290dfb799ebe6619c46850354bdfb176.bindPopup(popup_d38e81fb5452f2716f5a0f9cfd23bbf4)
#         ;
#
#
#
#
#             var marker_68f5e521dcd1416c9deb8a33efa10300 = L.marker(
#                 [-23.5505, -46.6333],
#                 {}
#             ).addTo(map_4460d19b0bf610777fb92a2dc43671f1);
#
#
#         var popup_4a512e61397b645ca4c3f7d12fa34e83 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3cad0836486d1b74ebedb06dd7ba3d34 = $(`&lt;div id=&quot;html_3cad0836486d1b74ebedb06dd7ba3d34&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;São Paulo, SP, Brasil&lt;/div&gt;`)[0];
#                 popup_4a512e61397b645ca4c3f7d12fa34e83.setContent(html_3cad0836486d1b74ebedb06dd7ba3d34);
#
#
#
#         marker_68f5e521dcd1416c9deb8a33efa10300.bindPopup(popup_4a512e61397b645ca4c3f7d12fa34e83)
#         ;
#
#
#
#
#             var marker_552826009b39aa9a6539b22557478a10 = L.marker(
#                 [-22.9068, -43.1729],
#                 {}
#             ).addTo(map_4460d19b0bf610777fb92a2dc43671f1);
#
#
#         var popup_2a1ecdccfddf66b5e10065a304546ffc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_243b392bb2c404a9cae8ca856a12b682 = $(`&lt;div id=&quot;html_243b392bb2c404a9cae8ca856a12b682&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Rio de Janeiro, RJ, Brasil&lt;/div&gt;`)[0];
#                 popup_2a1ecdccfddf66b5e10065a304546ffc.setContent(html_243b392bb2c404a9cae8ca856a12b682);
#
#
#
#         marker_552826009b39aa9a6539b22557478a10.bindPopup(popup_2a1ecdccfddf66b5e10065a304546ffc)
#         ;
#
#
#
#
#             var marker_439645c7b02b80045ca143d9dddf55d8 = L.marker(
#                 [-25.429, -49.2671],
#                 {}
#             ).addTo(map_4460d19b0bf610777fb92a2dc43671f1);
#
#
#         var popup_5cab8462ab5ec969efa2f18f0224d67a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2cab657e1c52d499ff51d35e241c052d = $(`&lt;div id=&quot;html_2cab657e1c52d499ff51d35e241c052d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Curitiba, PR, Brasil&lt;/div&gt;`)[0];
#                 popup_5cab8462ab5ec969efa2f18f0224d67a.setContent(html_2cab657e1c52d499ff51d35e241c052d);
#
#
#
#         marker_439645c7b02b80045ca143d9dddf55d8.bindPopup(popup_5cab8462ab5ec969efa2f18f0224d67a)
#         ;
#
#
#
#
#             var marker_1d2217acd2e10fe5f02fce4cb65ac4a3 = L.marker(
#                 [-19.9173, -43.9345],
#                 {}
#             ).addTo(map_4460d19b0bf610777fb92a2dc43671f1);
#
#
#         var popup_20703173a0ad4ba3d5d6d567a1d9ad89 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_326de2cc36cfb1b7dd74999d2ac3568d = $(`&lt;div id=&quot;html_326de2cc36cfb1b7dd74999d2ac3568d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Belo Horizonte, SC, Brasil&lt;/div&gt;`)[0];
#                 popup_20703173a0ad4ba3d5d6d567a1d9ad89.setContent(html_326de2cc36cfb1b7dd74999d2ac3568d);
#
#
#
#         marker_1d2217acd2e10fe5f02fce4cb65ac4a3.bindPopup(popup_20703173a0ad4ba3d5d6d567a1d9ad89)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscre
